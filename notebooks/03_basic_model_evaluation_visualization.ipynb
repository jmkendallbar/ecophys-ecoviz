# %% [markdown]
# # 03_Basic_Model_Evaluation
# notebook for showing the confusion matrix, accuracy, and maybe a few snippets of naps with the predictions aligned with actuals to show when the predictions are incorrect..?

# %%
import pandas as pd
import pytz
import datetime

# %%
import sys
sys.path.insert(0, '..')
import src.visualization.visualize as seal_viz
import src.models.build_model_LGBM as seal_model

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load features and model

# %%
# PST Timezone
pst_timezone = pytz.timezone('America/Los_Angeles')

# Read features and set index as datetimeindex
features_df = pd.read_csv('../data/processed/features/test12_Wednesday_07_features_with_labels.csv',
                          index_col=0)
features_df.index = pd.DatetimeIndex(features_df.index, tz=pst_timezone)

# %% [markdown]
# ## Generate predictions

# %%
fold_accs, class_accs, _, conf_matr, preds = seal_model.evaluate_model(features_df, 'Simple.Sleep.Code',
                                                                       return_preds=True, verbosity=-1)

# %%
preds = pd.concat(preds)

# %% [markdown]
# ## Model evaluation

# %%
#### Class accuracy in each fifth of the data (notic)

# %%
fold_accs

# %% [markdown]
# ## Plot naps

# %% [markdown]
# #### Nap 1

# %%
start_dt = datetime.datetime.strptime('10/25/2019 16:36:00', '%m/%d/%Y %H:%M:%S').replace(tzinfo=None).astimezone(pst_timezone)
end_dt = datetime.datetime.strptime('10/25/2019 16:50:00', '%m/%d/%Y %H:%M:%S').replace(tzinfo=None).astimezone(pst_timezone)
fig, ax = seal_viz.plot_nap(features_df, 'Simple.Sleep.Code', start_dt, end_dt, preds=preds)

# %% [markdown]
# #### Nap 2

# %%
start_dt = datetime.datetime.strptime('10/25/2019 17:26:00', '%m/%d/%Y %H:%M:%S').replace(tzinfo=None).astimezone(pst_timezone)
end_dt = datetime.datetime.strptime('10/25/2019 17:37:00', '%m/%d/%Y %H:%M:%S').replace(tzinfo=None).astimezone(pst_timezone)
fig, ax = seal_viz.plot_nap(features_df, 'Simple.Sleep.Code', start_dt, end_dt, preds=preds)

# %% [markdown]
# #### Nap 3

# %%
start_dt = datetime.datetime.strptime('10/25/2019 19:00:00', '%m/%d/%Y %H:%M:%S').replace(tzinfo=None).astimezone(pst_timezone)
end_dt = datetime.datetime.strptime('10/25/2019 19:14:00', '%m/%d/%Y %H:%M:%S').replace(tzinfo=None).astimezone(pst_timezone)
fig, ax = seal_viz.plot_nap(features_df, 'Simple.Sleep.Code', start_dt, end_dt, preds=preds)

# %% [markdown]
# #### Nap 4

# %%
start_dt = datetime.datetime.strptime('10/25/2019 21:50:00', '%m/%d/%Y %H:%M:%S').replace(tzinfo=None).astimezone(pst_timezone)
end_dt = datetime.datetime.strptime('10/25/2019 22:04:00', '%m/%d/%Y %H:%M:%S').replace(tzinfo=None).astimezone(pst_timezone)
fig, ax = seal_viz.plot_nap(features_df, 'Simple.Sleep.Code', start_dt, end_dt, preds=preds)
