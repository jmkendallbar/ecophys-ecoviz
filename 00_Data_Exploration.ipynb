# %% [markdown]
# <a href="https://colab.research.google.com/github/InteGerard/ecophys-ecoviz/blob/main/00_Data_Exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive/MAS_DSE_Capstone_Seal_Sleep/"
# Out:
# features_v1.zip				  test12_Wednesday_05_DAY4_PROCESSED.edf
# HR_test08_JKB_AB_L1.edf			  test33_HypoactiveHeidi_05_DAY1_PROCESSED.edf
# Scientific-Workflow.ppt			  test33_HypoactiveHeidi_05_DAY2_PROCESSED.edf
# Scientific-Workflow.pptx		  test33_HypoactiveHeidi_05_DAY3_PROCESSED.edf
# test12_Wednesday_05_ALL_PROCESSED.adicht  test33_HypoactiveHeidi_05_DAY4_PROCESSED.edf
# test12_Wednesday_05_ALL_PROCESSED.edf	  test33_HypoactiveHeidi_05_DAY5_PROCESSED.edf
# test12_Wednesday_05_DAY1_PROCESSED.edf	  test33_HypoactiveHeidi_06_Hypnogram_JKB_1Hz.csv
# test12_Wednesday_05_DAY2_PROCESSED.edf	  test33_HypoactiveHeidi_06_Hypnogram_JKB_30s.csv
# test12_Wednesday_05_DAY3_PROCESSED.edf	  Wednesday_features_ALL.csv

# %%
# !pip install yasa
# !pip install mne
# !pip install six
# !pip install pomegranate
# !pip install pyedflib
# !pip install sleepecg
# !pip install wfdb
# !pip install pytz

import yasa
import mne
import os
import sys
import scipy
import glob
import six
import wfdb
import pytz
import sklearn
import pomegranate
import pyedflib
import sleepecg
import datetime
import wfdb.processing
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as colors
#import entropy as ent
import seaborn as sns
from matplotlib import mlab as mlab
from sleepecg import detect_heartbeats
import matplotlib.gridspec as gs
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.4/92.4 kB 2.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.7/154.7 kB 10.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 33.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 44.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 51.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 11.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 2.3 MB/s eta 0:00:00
# ...
